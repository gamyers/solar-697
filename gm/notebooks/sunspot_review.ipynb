# %%
import pandas as pd

# %%
df = pd.read_json("../../data/sunspots/observed-solar-cycle-indices.json")

# %%
df_sun = df[(df['time-tag']>="1998-01") & (df['time-tag']<="2020-12")].reset_index(drop=True)

# %%
df_sun['time-tag'] = pd.to_datetime(df_sun["time-tag"], infer_datetime_format=True, yearfirst=True, format="%Y-%m")
df_sun.set_index("time-tag", inplace=True)
df_sun.index=df_sun.index.to_period("M").to_timestamp("M")

# %%
# Out:
#              ssn  smoothed_ssn  observed_swpc_ssn  smoothed_swpc_ssn  f10.7  \
# time-tag
# 2019-01-31   7.7           5.4               8.29                5.2  71.58
# 2019-02-28   0.8           5.0               0.00                4.9  70.59
# 2019-03-31   9.4           4.6               9.10                4.5  71.52
# 2019-04-30   9.1           4.3               8.50                4.2  72.47
# 2019-05-31   9.9           3.9               9.97                3.9  71.32
# 2019-06-30   1.2           3.7               1.93                3.7  68.13
# 2019-07-31   0.9           3.5               0.74                3.6  67.25
# 2019-08-31   0.5           3.4               0.74                3.5  67.05
# 2019-09-30   1.1           3.1               0.80                3.2  68.00
# 2019-10-31   0.4           2.6               0.71                2.7  67.46
# 2019-11-30   0.5           2.0               0.80                2.1  70.18
# 2019-12-31   1.5           1.8               1.87                1.9  70.93
# 2020-01-31   6.2           2.2               5.94                2.3  72.32
# 2020-02-29   0.2           2.7               0.38                2.8  70.90
# 2020-03-31   1.5           3.0               1.19                3.1  70.19
# 2020-04-30   5.2           3.6               4.83                3.6  69.56
# 2020-05-31   0.2           5.6               0.00                5.3  69.21
# 2020-06-30   5.8           7.9               5.87                7.4  69.70
# 2020-07-31   6.1           9.0               6.48                8.4  69.47
# 2020-08-31   7.5           9.5               7.84                9.0  71.66
# 2020-09-30   0.6          10.5               0.80               10.0  70.56
# 2020-10-31  14.6          11.9              13.19               11.5  74.59
# 2020-11-30  34.5          13.6              28.97               13.1  90.11
# 2020-12-31  23.1          15.3              22.52               14.7  87.28
#
#             smoothed_f10.7
# time-tag
# 2019-01-31            70.0
# 2019-02-28            69.9
# 2019-03-31            69.8
# 2019-04-30            69.7
# 2019-05-31            69.6
# 2019-06-30            69.7
# 2019-07-31            69.8
# 2019-08-31            69.8
# 2019-09-30            69.8
# 2019-10-31            69.6
# 2019-11-30            69.4
# 2019-12-31            69.4
# 2020-01-31            69.5
# 2020-02-29            69.8
# 2020-03-31            70.1
# 2020-04-30            70.5
# 2020-05-31            71.7
# 2020-06-30            73.2
# 2020-07-31            74.0
# 2020-08-31            74.3
# 2020-09-30            74.7
# 2020-10-31            75.2
# 2020-11-30            75.7
# 2020-12-31            76.4
